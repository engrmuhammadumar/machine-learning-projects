# %%
import cv2

# %%
img1 = cv2.imread(r"Computer-Vision-with-Python/DATA/dog_backpack.png")
img1 =cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img2 = cv2.imread(r"E:\Courses\Computer Vision\Computer-Vision-with-Python\DATA\watermark_no_copy.png")
img2 =cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
img1.shape
# Out:
# (1401, 934, 3)

# %%
img2.shape
# Out:
# (1280, 1277, 3)

# %%
img1 = cv2.resize(img1, (1200,1200))
img2 = cv2.resize(img2, (1200,1200))

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
blended = cv2.addWeighted(src1=img1, alpha = 0.8, src2 = img2, beta = 0.2, gamma= 0)
plt.imshow(blended)

# %%
#OVERLAY SMALL IMAGES ON TOP OF A LARGER IMAGE (NO BLENDING)
#numpy reassignemnt

# %%
img1 = cv2.imread(r"Computer-Vision-with-Python/DATA/dog_backpack.png")
img1 =cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img2 = cv2.imread(r"E:\Courses\Computer Vision\Computer-Vision-with-Python\DATA\watermark_no_copy.png")
img2 =cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

# %%
img2 = cv2.resize(img2, (600,600))
plt.imshow(img2)

# %%
plt.imshow(img1)

# %%
large_img = img1
small_img = img2

# %%
x_offset = 0
y_offset = 0

# %%
x_end = x_offset + small_img.shape[1]
y_end = y_offset + small_img.shape[0]

# %%
small_img.shape
# Out:
# (600, 600, 3)

# %%
large_img[y_offset:y_end, x_offset:x_end] = small_img

# %%
plt.imshow(large_img)

# %%
img1.shape
# Out:
# (1401, 934, 3)

# %%
x_offset = 934 - 600
y_offset = 1402- 600

# %%
img2.shape
# Out:
# (600, 600, 3)

# %%
rows, cols, channels = img2.shape

# %%
rows
# Out:
# 600

# %%
cols
# Out:
# 600

# %%
roi = img1[y_offset: 1401, x_offset:943]
plt.imshow(roi)

# %%
import cv2

# %%
import matplotlib.pyplot as plt

# %%
img = cv2.imread(r"E:\Courses\Computer Vision\Computer-Vision-with-Python\DATA\rainbow.jpg", 0)

# %%
plt.imshow(img, cmap = "gray")

# %%
ret, thresh1 = cv2.threshold(img,127,255, cv2.THRESH_TRUNC)

# %%
img.max()
# Out:
# 214

# %%
ret
# Out:
# 127.0

# %%
plt.imshow(thresh1, cmap='gray')

# %%
ret,thresh5 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO_INV)
plt.imshow(thresh5,cmap='gray')

# %%
ret,thresh4 = cv2.threshold(img,127,255,cv2.THRESH_TOZERO)
plt.imshow(thresh4,cmap='gray')

# %%
img = cv2.imread(r"E:\Courses\Computer Vision\Computer-Vision-with-Python\DATA\crossword.jpg",0)

# %%
def show_pic(img):
    fig = plt.figure(figsize=(15,15))
    ax = fig.add_subplot(111)
    ax.imshow(img,cmap='gray')
